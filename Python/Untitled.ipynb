# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("API_DT.DOD.MIBR.CD_DS2_en_csv_v2_716566.csv")
a=a.set_index("Country Name")
x=a.loc["China"]
x=x.iloc[3:]
plt.figure()
plt.plot(x.index,x.values)
plt.xticks([9,14,19,24,29,34,39,44,49,54,59])
# Out:
# ([<matplotlib.axis.XTick at 0x17bc40f2550>,
# ...
#  <a list of 11 Text xticklabel objects>)
