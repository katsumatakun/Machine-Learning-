# %%
using Distributions, StatsPlots, Plots

# %%
N = 1000
x = rand(Normal(),N)
y = rand(Normal(),N)
# Out:
# 1000-element Array{Float64,1}:
#   1.220169078544267
#  -0.09842662722382059
#   0.40756622306820894
#  -1.0406766524501159
#  -0.3086213098773102
#  -0.13461217149706547
#  -0.5626911603575323
#  -0.04015719414690099
#   0.49255318015033633
#   0.7036538955409569
#   0.716460330011181
#   0.4980896637404718
#   0.6421152582396534
#   ⋮
#   0.8436711014937223
#   1.1603124433294065
#  -0.9065760910951528
#  -2.537792893052298
#   0.9394486566320678
#   0.8077803549564387
#   0.8169063093318245
#   0.49583439602907287
#  -0.8617455257062236
#   0.6291610990328718
#  -0.11199692256240301
#   0.3033958069908837

# %%
scatter(x,y)

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
x_2 = rand(Uniform(10,100),N)
y_2 = 2*x_2 .+5 .+rand(Normal(100,20),N)
# Out:
# 1000-element Array{Float64,1}:
#  244.84736293416205
#  307.7937337809254
#  136.7226516297899
#  271.29948478248684
#  200.36403240733307
#  172.0488020905675
#  248.53956330531065
#  305.6806397695064
#  117.08753145898328
#  142.45553477204913
#  278.5173166146232
#  117.6868488785161
#  253.5236074470651
#    ⋮
#  258.3246432112867
#  182.5720899551252
#  181.44162933383058
#  217.1296258407239
#  237.80948902086703
#  187.165809287902
#  186.56956545774023
#  267.6980995815328
#  213.53514045439493
#  275.1680521774422
#  243.14107879717713
#  143.7907585320533

# %%
scatter(x_2,y_2)

# %%
using Pkg

# %%
Pkg.add("DataFrames")
# Out:
#   Updating registry at `C:\Users\masahiro\.julia\registries\General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 %.1 %==================>                      ]  43.7 % [======================>                  ]  54.0 %]  62.1 %Fetching: [============================>            ]  68.9 %>        ]  78.8 %=======================================> ]  96.2 % Resolving package versions...
#  Installed InvertedIndices ─── v1.0.0
#  Installed PooledArrays ────── v0.5.3
#  Installed Compat ──────────── v3.5.0
#  Installed CategoricalArrays ─ v0.7.7
#  Installed StatsBase ───────── v0.32.1
#  Installed DataFrames ──────── v0.20.2
#   Updating `C:\Users\masahiro\.julia\environments\v1.3\Project.toml`
#   [a93c6f00] + DataFrames v0.20.2
#   Updating `C:\Users\masahiro\.julia\environments\v1.3\Manifest.toml`
#   [324d7699] + CategoricalArrays v0.7.7
#   [34da2185] + Compat v3.5.0
# ...

# %%
using DataFrames
df = DataFrame(a=[1,2,3], b=["a", "b", "c"])
# Out:
# ┌ Info: Precompiling DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0]
# └ @ Base loading.jl:1273
# 3×2 DataFrame
# │ Row │ a     │ b      │
# │     │ Int64 │ String │
# ├─────┼───────┼────────┤
# │ 1   │ 1     │ a      │
# │ 2   │ 2     │ b      │
# │ 3   │ 3     │ c      │

# %%
Pkg.add("CSV")
# Out:
#  Resolving package versions...
#  Installed WeakRefStrings ─ v0.6.2
#  Installed FilePathsBase ── v0.7.0
#  Installed CSV ──────────── v0.5.24
#   Updating `C:\Users\masahiro\.julia\environments\v1.3\Project.toml`
#   [336ed68f] + CSV v0.5.24
#   Updating `C:\Users\masahiro\.julia\environments\v1.3\Manifest.toml`
#   [336ed68f] + CSV v0.5.24
#   [48062228] + FilePathsBase v0.7.0
#   [ea10d353] + WeakRefStrings v0.6.2

# %%
using CSV
# Out:
# ┌ Info: Precompiling CSV [336ed68f-0bac-5ca0-87d4-7b16caf5d00b]
# └ @ Base loading.jl:1273

# %%
df = DataFrame(CSV.FCredit.csve("Credit.csv"))
# Out:
# 400×12 DataFrame. Omitted printing of 5 columns
# │ Row │ Column1 │ Income  │ Limit │ Rating │ Cards │ Age   │ Education │
# │     │ Int64   │ Float64 │ Int64 │ Int64  │ Int64 │ Int64 │ Int64     │
# ├─────┼─────────┼─────────┼───────┼────────┼───────┼───────┼───────────┤
# │ 1   │ 1       │ 14.891  │ 3606  │ 283    │ 2     │ 34    │ 11        │
# │ 2   │ 2       │ 106.025 │ 6645  │ 483    │ 3     │ 82    │ 15        │
# │ 3   │ 3       │ 104.593 │ 7075  │ 514    │ 4     │ 71    │ 11        │
# │ 4   │ 4       │ 148.924 │ 9504  │ 681    │ 3     │ 36    │ 11        │
# │ 5   │ 5       │ 55.882  │ 4897  │ 357    │ 2     │ 68    │ 16        │
# │ 6   │ 6       │ 80.18   │ 8047  │ 569    │ 4     │ 77    │ 10        │
# │ 7   │ 7       │ 20.996  │ 3388  │ 259    │ 2     │ 37    │ 12        │
# │ 8   │ 8       │ 71.408  │ 7114  │ 512    │ 2     │ 87    │ 9         │
# │ 9   │ 9       │ 15.125  │ 3300  │ 266    │ 5     │ 66    │ 13        │
# ...

# %%
df.Income === df[!, :Income]
df[:,:Income]===df.Income #df[:,:Income] make a copy. Others doesn't change will be affected.
df[:,:Income]==df.Income
df.Income===df[!,2]
df.Income===df[:,2]
df.Income==df[:,2]
income = :Income
df[!, income]===df.Income
df[:, income]===df.Income
df[:, income]==df.Income
# Out:
# true

# %%
names(df) ##return column names
# Out:
# 12-element Array{Symbol,1}:
#  :Column1
#  :Income
#  :Limit
#  :Rating
#  :Cards
#  :Age
#  :Education
#  :Gender
#  :Student
#  :Married
#  :Ethnicity
#  :Balance

# %%
eg1 = DataFrame() ##create an empty df 
eg1.A = 1:8 ##add columns
eg1.B = ["M", "F", "F", "M", "F", "M", "M", "F"]
eg1
# Out:
# 8×2 DataFrame
# │ Row │ A     │ B      │
# │     │ Int64 │ String │
# ├─────┼───────┼────────┤
# │ 1   │ 1     │ M      │
# │ 2   │ 2     │ F      │
# │ 3   │ 3     │ F      │
# │ 4   │ 4     │ M      │
# │ 5   │ 5     │ F      │
# │ 6   │ 6     │ M      │
# │ 7   │ 7     │ M      │
# │ 8   │ 8     │ F      │

# %%
size(df,1) ##return num rows
size(df,2) ##return num colmuns
# Out:
# 12

# %%
eg2 = DataFrame(A = Int[], B=String[]) ##create an empty df with column data type specified
# Out:
# 0×2 DataFrame

# %%
push!(eg2, (1, "M")) ##insert rows to df
push!(eg2, (2, "M"))
push!(eg2, [3, "N"])
# Out:
# 7×2 DataFrame
# │ Row │ A     │ B      │
# │     │ Int64 │ String │
# ├─────┼───────┼────────┤
# │ 1   │ 1     │ M      │
# │ 2   │ 1     │ M      │
# │ 3   │ 1     │ M      │
# │ 4   │ 2     │ M      │
# │ 5   │ 1     │ M      │
# │ 6   │ 2     │ M      │
# │ 7   │ 3     │ N      │

# %%
x = Dict(:B => "F", :A => 3)
push!(eg2, x) ##add row by using dict
# Out:
# 8×2 DataFrame
# │ Row │ A     │ B      │
# │     │ Int64 │ String │
# ├─────┼───────┼────────┤
# │ 1   │ 1     │ M      │
# │ 2   │ 1     │ M      │
# │ 3   │ 1     │ M      │
# │ 4   │ 2     │ M      │
# │ 5   │ 1     │ M      │
# │ 6   │ 2     │ M      │
# │ 7   │ 3     │ N      │
# │ 8   │ 3     │ F      │

# %%
first(df,6) ##display the first 6 rows
last(df,6) ##display the last 6 rows
# Out:
# 6×12 DataFrame. Omitted printing of 5 columns
# │ Row │ Column1 │ Income  │ Limit │ Rating │ Cards │ Age   │ Education │
# │     │ Int64   │ Float64 │ Int64 │ Int64  │ Int64 │ Int64 │ Int64     │
# ├─────┼─────────┼─────────┼───────┼────────┼───────┼───────┼───────────┤
# │ 1   │ 395     │ 49.794  │ 5758  │ 410    │ 4     │ 40    │ 8         │
# │ 2   │ 396     │ 12.096  │ 4100  │ 307    │ 3     │ 32    │ 13        │
# │ 3   │ 397     │ 13.364  │ 3838  │ 296    │ 5     │ 65    │ 17        │
# │ 4   │ 398     │ 57.872  │ 4171  │ 321    │ 5     │ 67    │ 12        │
# │ 5   │ 399     │ 37.728  │ 2525  │ 192    │ 1     │ 44    │ 13        │
# │ 6   │ 400     │ 18.701  │ 5524  │ 415    │ 5     │ 64    │ 7         │

# %%
eg3 = DataFrame(a=1:2, b=[1.0, missing], c=categorical('a':'b'), d= [1//2, missing])
# Out:
# 2×4 DataFrame
# │ Row │ a     │ b        │ c            │ d         │
# │     │ Int64 │ Float64⍰ │ Categorical… │ Rationa…⍰ │
# ├─────┼───────┼──────────┼──────────────┼───────────┤
# │ 1   │ 1     │ 1.0      │ 'a'          │ 1//2      │
# │ 2   │ 2     │ missing  │ 'b'          │ missing   │

# %%
df[1:3,:] ##row1 to row3 with all columns
df[[1,3,10],:] ##row1, row3, and row10 with all colmuns
# Out:
# 3×12 DataFrame. Omitted printing of 5 columns
# │ Row │ Column1 │ Income  │ Limit │ Rating │ Cards │ Age   │ Education │
# │     │ Int64   │ Float64 │ Int64 │ Int64  │ Int64 │ Int64 │ Int64     │
# ├─────┼─────────┼─────────┼───────┼────────┼───────┼───────┼───────────┤
# │ 1   │ 1       │ 14.891  │ 3606  │ 283    │ 2     │ 34    │ 11        │
# │ 2   │ 3       │ 104.593 │ 7075  │ 514    │ 4     │ 71    │ 11        │
# │ 3   │ 10      │ 71.061  │ 6819  │ 491    │ 3     │ 41    │ 19        │

# %%
df[:, [:Income, :Cards]] ##all rows with column Income and Cards
df[1:3, [:Cards, :Income]] ##row1 to row3 with column Cards and Income
df[[3,1], [:Rating]] ##row3 and row1 with column Rating
# Out:
# 2×1 DataFrame
# │ Row │ Rating │
# │     │ Int64  │
# ├─────┼────────┤
# │ 1   │ 514    │
# │ 2   │ 283    │

# %%
df[!, [:Cards]] ##return a dataframe
df[!, [:Rating]] == df[:, [:Rating]] ##both return a dataframe
# Out:
# true

# %%
df[!,:Income] ##return an array
df[!,:Income] == df[:,:Income] ##Both return arrays
# Out:
# true

# %%
eg4 = DataFrame(x1=1,x2=2,y=3, r=1)
# Out:
# 1×4 DataFrame
# │ Row │ x1    │ x2    │ y     │ r     │
# │     │ Int64 │ Int64 │ Int64 │ Int64 │
# ├─────┼───────┼───────┼───────┼───────┤
# │ 1   │ 1     │ 2     │ 3     │ 1     │

# %%
eg4[!,r"x"] ##using reqular expression
eg4[!, Not(:x1)] ##all but column x1
# Out:
# 1×2 DataFrame
# │ Row │ x2    │ y     │
# │     │ Int64 │ Int64 │
# ├─────┼───────┼───────┤
# │ 1   │ 2     │ 3     │

# %%
eg4[:, All(r"x",:)] ##move columns containing "x" to left
eg4[:, All(Not(r"x"),:)] ##move columns containing "x" to right
# Out:
# 1×4 DataFrame
# │ Row │ y     │ r     │ x1    │ x2    │
# │     │ Int64 │ Int64 │ Int64 │ Int64 │
# ├─────┼───────┼───────┼───────┼───────┤
# │ 1   │ 3     │ 1     │ 1     │ 2     │

# %%
df[df.Rating .> 400, :] ##all rows whose Rating > 400
df[(df.Rating .>400) .& (14 .< df.Education .< 19), :] ##Rating >400 and 14 < Education < 19
# Out:
# 45×12 DataFrame. Omitted printing of 5 columns
# │ Row │ Column1 │ Income  │ Limit │ Rating │ Cards │ Age   │ Education │
# │     │ Int64   │ Float64 │ Int64 │ Int64  │ Int64 │ Int64 │ Int64     │
# ├─────┼─────────┼─────────┼───────┼────────┼───────┼───────┼───────────┤
# │ 1   │ 2       │ 106.025 │ 6645  │ 483    │ 3     │ 82    │ 15        │
# │ 2   │ 22      │ 37.348  │ 6378  │ 458    │ 1     │ 72    │ 17        │
# │ 3   │ 30      │ 26.813  │ 5611  │ 411    │ 4     │ 55    │ 16        │
# │ 4   │ 42      │ 113.659 │ 7659  │ 538    │ 2     │ 66    │ 15        │
# │ 5   │ 45      │ 31.861  │ 6375  │ 469    │ 3     │ 25    │ 16        │
# │ 6   │ 69      │ 27.847  │ 5619  │ 418    │ 2     │ 78    │ 15        │
# │ 7   │ 87      │ 55.367  │ 6340  │ 448    │ 1     │ 33    │ 15        │
# │ 8   │ 91      │ 20.191  │ 5767  │ 431    │ 4     │ 42    │ 16        │
# │ 9   │ 92      │ 48.498  │ 6040  │ 456    │ 3     │ 47    │ 16        │
# ...

# %%
df[in.(df.Education, Ref([11, 16, 19])), :] ##all rows whose value in Education is exactly 11,16,or19
df[in([11,16,19]).(df.Education),:] ## same as avobe
# Out:
# 93×12 DataFrame. Omitted printing of 5 columns
# │ Row │ Column1 │ Income  │ Limit │ Rating │ Cards │ Age   │ Education │
# │     │ Int64   │ Float64 │ Int64 │ Int64  │ Int64 │ Int64 │ Int64     │
# ├─────┼─────────┼─────────┼───────┼────────┼───────┼───────┼───────────┤
# │ 1   │ 1       │ 14.891  │ 3606  │ 283    │ 2     │ 34    │ 11        │
# │ 2   │ 3       │ 104.593 │ 7075  │ 514    │ 4     │ 71    │ 11        │
# │ 3   │ 4       │ 148.924 │ 9504  │ 681    │ 3     │ 36    │ 11        │
# │ 4   │ 5       │ 55.882  │ 4897  │ 357    │ 2     │ 68    │ 16        │
# │ 5   │ 10      │ 71.061  │ 6819  │ 491    │ 3     │ 41    │ 19        │
# │ 6   │ 12      │ 15.045  │ 1311  │ 138    │ 3     │ 64    │ 16        │
# │ 7   │ 21      │ 17.7    │ 2860  │ 235    │ 4     │ 63    │ 16        │
# │ 8   │ 26      │ 14.09   │ 4323  │ 326    │ 5     │ 25    │ 16        │
# │ 9   │ 28      │ 32.793  │ 4534  │ 333    │ 2     │ 44    │ 16        │
# ...

# %%
eg5 = DataFrame(x1=1,x2=2,y=3)
# Out:
# 1×3 DataFrame
# │ Row │ x1    │ x2    │ y     │
# │     │ Int64 │ Int64 │ Int64 │
# ├─────┼───────┼───────┼───────┤
# │ 1   │ 1     │ 2     │ 3     │

# %%
select(eg5,Not(:x1)) ##drop column x1
select(eg5, r"x") ##select columns containing x
# Out:
# 1×2 DataFrame
# │ Row │ x1    │ x2    │
# │     │ Int64 │ Int64 │
# ├─────┼───────┼───────┤
# │ 1   │ 1     │ 2     │

# %%
select(eg5, :x1) ##select always return dataframe
# Out:
# 1×1 DataFrame
# │ Row │ x1    │
# │     │ Int64 │
# ├─────┼───────┤
# │ 1   │ 1     │

# %%
eg6 = select(eg5, :x1) ## make a copy
eg6.x1 === eg5.x1
# Out:
# false

# %%
eg7 = select(eg5, :x1, copycols=false) ##points to the same column(object)
eg7.x1===eg5.x1
# Out:
# true

# %%
describe(df) ##returns a data frame summarizing elementary statistics and info about each colmun
# Out:
# 12×8 DataFrame. Omitted printing of 2 columns
# │ Row │ variable  │ mean    │ min              │ median  │ max       │ nunique │
# │     │ Symbol    │ Union…  │ Any              │ Union…  │ Any       │ Union…  │
# ├─────┼───────────┼─────────┼──────────────────┼─────────┼───────────┼─────────┤
# │ 1   │ Column1   │ 200.5   │ 1                │ 200.5   │ 400       │         │
# │ 2   │ Income    │ 45.2189 │ 10.354           │ 33.1155 │ 186.634   │         │
# │ 3   │ Limit     │ 4735.6  │ 855              │ 4622.5  │ 13913     │         │
# │ 4   │ Rating    │ 354.94  │ 93               │ 344.0   │ 982       │         │
# │ 5   │ Cards     │ 2.9575  │ 1                │ 3.0     │ 9         │         │
# │ 6   │ Age       │ 55.6675 │ 23               │ 56.0    │ 98        │         │
# │ 7   │ Education │ 13.45   │ 5                │ 14.0    │ 20        │         │
# │ 8   │ Gender    │         │ Female           │         │ Male      │ 2       │
# ...

# %%
describe(df[!, [:Income]])##df containing info about Income colmun
# Out:
# 1×8 DataFrame. Omitted printing of 1 columns
# │ Row │ variable │ mean    │ min     │ median  │ max     │ nunique │ nmissing │
# │     │ Symbol   │ Float64 │ Float64 │ Float64 │ Float64 │ Nothing │ Nothing  │
# ├─────┼──────────┼─────────┼─────────┼─────────┼─────────┼─────────┼──────────┤
# │ 1   │ Income   │ 45.2189 │ 10.354  │ 33.1155 │ 186.634 │         │          │

# %%
using Statistics

# %%
mean(df.Income)
# Out:
# 45.21888500000001

# %%
aggregate(df[!,[:Income, :Rating, :Education]],sum)
aggregate(df[!, [:Income, :Rating, :Cards]], [sum, prod])
# Out:
# 1×6 DataFrame. Omitted printing of 1 columns
# │ Row │ Income_sum │ Rating_sum │ Cards_sum │ Income_prod │ Rating_prod │
# │     │ Float64    │ Int64      │ Int64     │ Float64     │ Int64       │
# ├─────┼────────────┼────────────┼───────────┼─────────────┼─────────────┤
# │ 1   │ 18087.6    │ 141976     │ 1183      │ Inf         │ 0           │

# %%
eg9 = DataFrame(x=[3,1,2])
sort!(eg9)
eg9.x[1]=100
eg9
# Out:
# 3×1 DataFrame
# │ Row │ x     │
# │     │ Int64 │
# ├─────┼───────┤
# │ 1   │ 100   │
# │ 2   │ 2     │
# │ 3   │ 3     │

# %%
1/(0.33*0.5+0.41*0.5)
# Out:
# 2.7027027027027026

# %%
0.33*0.5*2.7
0.41*0.5*2.7
# Out:
# 0.5535
