# %%
using Plots, Distributions

# %%
f(x) = 8x^2+4
g(x) = 8x^2-10
# Out:
# g (generic function with 1 method)

# %%
xvec = -10:10
# Out:
# -10:10

# %%
plot(xvec,f.(xvec))

# %%
plot!(xvec,g.(xvec))
